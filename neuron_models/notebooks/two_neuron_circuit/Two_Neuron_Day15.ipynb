# %% [markdown]
# # Two Neuron Day 15 (30/01/2026)
# ***Phase 5- Day 6***
#
# *Bonus - Minimal 2- Neuron Silmulation*

# %% [markdown]
# **Neuron A**

# %%
import numpy as np
import matplotlib.pyplot as plt
#Time parameters
dt=0.1
T=100
time=np.arange(0,T,dt)

# Neuron A parameters
V_rest_A=-65
V_A=np.zeros(len(time))
V_A[0]=V_rest_A

#Input Current (constant)
I_A = 6
tau_A=10

# Spikes A
V_th_A = -63
V_reset_A = -65
spikes_A= np.zeros(len(time))

#Refractory period 
refractory_period_A = 2
refractory_steps_A = int(refractory_period_A / dt)
refractory_timer_A= 0

#Noise
noise_std = 1
noise = np.random.normal(0,noise_std,len(time))

#Voltage update loop
for t in range(1,len(time)):
    if refractory_timer_A >0:
        V_A[t] = V_reset_A
        refractory_timer_A -= 1

    else:
        I_t = I_A+noise[t]
        dV_A= (-(V_A[t-1] - V_rest_A ) + I_t) * (dt/tau_A)
        V_A[t] = V_A[t-1] + dV_A

        if V_A[t] >= V_th_A :
            spikes_A[t] = 1
            V_A[t] = V_reset_A
            refractory_timer_A = refractory_steps_A

#Firing rate calculation
total_spikes_A = np.sum(spikes_A)
total_time_sec_A= T/1000

firing_rate_A = total_spikes_A / total_time_sec_A
firing_rate_A
# Out:
# np.float64(160.0)

# %% [markdown]
# **Spike Count Neuron A**

# %%
spike_count_A = np.sum(spikes_A)
spike_count_A
# Out:
# np.float64(16.0)

# %% [markdown]
# **Neuron A Graph**

# %%
plt.figure(figsize=(4,3))
plt.plot(time,V_A)
plt.xlabel("Time (ms)")
plt.ylabel("Voltage (mV)")
plt.title("Neuron A")
plt.show()

# %% [markdown]
# **Spike Train Neuron A**

# %%
spike_times_A = time[spikes_A == 1]

plt.figure(figsize=(10,2))
plt.vlines(spike_times_A,ymin=0,ymax=1)
plt.xlabel("Time (ms)")
plt.yticks([])
plt.title("Spike Train Neuron A")
plt.show()

# %% [markdown]
# **Neuron B**

# %%
#Neuron A parameters 
V_rest_B = -65
V_B = np.zeros(len(time))
V_B[0] = V_rest_B

#Input Current (comes from Neuron A) 
# Synapthic connection from A-> B
w_AB = 15 + 10 * np.sin(2 * np.pi * np.arange(len(time)) / len(time))
I_B= np.zeros(len(time))
syn_current_B = np.zeros(len(time))

#Inhibitory synapse from A-> B
w_AiB = 4.0
syn_current_inh_B = np.zeros(len(time))

# Synaptic decay constants
alpha_exc = 0.90    # slow decay (excitation accumulates)
alpha_inh = 0.85    # faster decay (inhibition is brief)

#Spikes
V_th_B = -63
V_reset_B = -65
spikes_B = np.zeros(len(time))

#Refractory period
refractory_period_B = 2
refractory_steps_B = int(refractory_period_B / dt)
refractory_timer_B =0

# Voltage update loop for Neuron B
for t in range(1,len(time)):
    # Excitatory synapse (A -> B)
    syn_current_B[t] = (
        alpha_exc * syn_current_B[t-1]
        + w_AB[t] * spikes_A[t-1]
    )

    # Inhibitory synapse (A -> B)
    syn_current_inh_B[t] = (
        alpha_inh * syn_current_inh_B[t-1]
        + w_AiB * spikes_A[t-1]
    )

    # Net synaptic input
    I_B[t] = syn_current_B[t] - syn_current_inh_B[t]

    if refractory_timer_B>0:
        V_B[t] = V_reset_B
        refractory_timer_B-=1

    else:
        dV_B = (-(V_B[t-1] - V_rest_B) + I_B[t]) * (dt / tau_A)
        V_B[t] = V_B[t-1] + dV_B

        if V_B[t] >= V_th_B:
            spikes_B[t]=1
            V_B[t] = V_reset_B
            refractory_timer_B = refractory_steps_B

#Firing rate calculation
total_spikes_B = np.sum(spikes_B)
total_time_sec_B= T/1000

firing_rate_B = total_spikes_B / total_time_sec_B
firing_rate_B
# Out:
# np.float64(40.0)

# %% [markdown]
# **Spike Count Neuron B**

# %%
spike_count_B = np.sum(spikes_B)
spike_count_B
# Out:
# np.float64(4.0)

# %% [markdown]
# **Neuron B Graph**

# %%
plt.figure(figsize=(4,3))
plt.plot(time,V_B)
plt.xlabel("Time (ms)")
plt.ylabel("Voltage (mV)")
plt.title("Neuron B")
plt.show()

# %% [markdown]
# **Spike Train Neuron B**

# %%
spike_times_B = time[spikes_B == 1]

plt.figure(figsize = (10,2))
plt.vlines(spike_times_B,ymin=0,ymax=1)
plt.xlabel("Time (ms)")
plt.yticks([])
plt.title("Spike Train Neuron B")
plt.show()

# %% [markdown]
# **Inter-Spike Interal (ISI)**

# %%
spike_times_A = time[spikes_A == 1]
spike_times_B = time[spikes_B == 1]

isi_A = np.diff(spike_times_A)
isi_B = np.diff(spike_times_B)

len(isi_A),len(isi_B)
# Out:
# (15, 3)

# %%
# mean ISI
mean_isi_A = np.mean(isi_A)
mean_isi_B = np.mean(isi_B)

mean_isi_A,mean_isi_B
# Out:
# (np.float64(6.113333333333333), np.float64(12.433333333333332))

# %%
# isi variance
std_isi_A = np.std(isi_A)
std_isi_B = np.std(isi_B)

std_isi_A,std_isi_B
# Out:
# (np.float64(0.13597385369580767), np.float64(0.8730533902472538))

# %%
# Coefficient of Variations (CV)
cv_A = np.std(isi_A)/ np.mean(isi_A)
cv_B = np.std(isi_B)/ np.mean(isi_B)
cv_A,cv_B
# Out:
# (np.float64(0.02224217890334913), np.float64(0.07021877133355929))

# %% [markdown]
# **Plot ISI for A**

# %%
plt.figure(figsize=(6,4))
plt.plot(isi_A,'o')
plt.xlabel("ISI (ms)")
plt.ylabel("Count")
plt.title("ISI Distribution - Neuron A")
plt.show()

# %% [markdown]
# Plotting inter-spike intervals (ISI) as individual values shows that all ISIs collapse to a single constant value.
# This indicates highly regular, tonic firing behavior of the neuron under constant input.
# Such deterministic firing patterns are characteristic of LIF neurons without noise or time-varying inputs.
# This regular baseline serves as a reference for later comparisons involving inhibition, noise, or modulation.

# %% [markdown]
# **Plot ISI for B**

# %%
plt.figure(figsize=(6,4))
plt.plot(isi_B,'o')
plt.xlabel("ISI (ms)")
plt.ylabel("Count")
plt.title("ISI Distribution - Neuron B")
plt.show()

# %% [markdown]
# # Feature Vectors

# %%
# Feature Vector Neuron A
features_A = {
    "spike_count" : spike_count_A,
    "firing_rate" : firing_rate_A,
    "mean_isi" : np.mean(isi_A),
    "std_isi" : np.std(isi_A),
    "cv" : np.std(isi_A) / np.mean(isi_A)
}

features_A
# Out:
# {'spike_count': np.float64(16.0),
#  'firing_rate': np.float64(160.0),
#  'mean_isi': np.float64(6.113333333333333),
#  'std_isi': np.float64(0.13597385369580767),
#  'cv': np.float64(0.02224217890334913)}

# %%
# Feature Vector Neuron B
if len(isi_B) > 1:
    mean_isi_B = np.mean(isi_B)
    std_isi_B = np.std(isi_B)
    cv_B = std_isi_B / mean_isi_B
else:
    mean_isi_B = np.nan
    std_isi_B = np.nan
    cv_B = np.nan

features_B = {
    "spike_count" : spike_count_B,
    "firing_rate" : firing_rate_B,
    "mean_isi" : mean_isi_B,
    "std_isi" : std_isi_B,
    "cv" : cv_B
}

features_B
# Out:
# {'spike_count': np.float64(4.0),
#  'firing_rate': np.float64(40.0),
#  'mean_isi': np.float64(12.433333333333332),
#  'std_isi': np.float64(0.8730533902472538),
#  'cv': np.float64(0.07021877133355929)}

# %%
#Feature Table
import pandas as pd

feature_table = pd.DataFrame(
    [features_A,features_B],
    index=["Neuron_A", "Neuron_B"]
)
feature_table
# Out:
#           spike_count  firing_rate   mean_isi   std_isi        cv
# Neuron_A         16.0        160.0   6.113333  0.135974  0.022242
# Neuron_B          4.0         40.0  12.433333  0.873053  0.070219

# %% [markdown]
# ## Simulation

# %%
#Neuron A
input_currents = [2,4,6,8]
def run_simulation(I_value):
    V_rest = -65
    V_th = -63
    V_reset = -65
    tau = 10
    dt = 0.1
    T = 100
    time = np.arange(0, T, dt)
    noise_std = 1
    noise = np.random.normal(0,noise_std,len(time))

    V = np.zeros(len(time))
    V[0] = V_rest
    spikes = np.zeros(len(time))

    for t in range(1, len(time)):
        I_t = I_value + noise[t]
        dV = (-(V[t-1] - V_rest) + I_t) * (dt / tau)
        V[t] = V[t-1] + dV

        if V[t] >= V_th:
            spikes[t] = 1
            V[t] = V_reset

    spike_times = time[spikes == 1]
    isi = np.diff(spike_times)

    spike_count = np.sum(spikes)
    firing_rate = spike_count / (T / 1000)

    if len(isi) > 1:
        mean_isi = np.mean(isi)
        std_isi = np.std(isi)
        cv = std_isi / mean_isi
    else:
        mean_isi = std_isi = cv = np.nan

    return {
        "I": I_value,
        "spike_count": spike_count,
        "firing_rate": firing_rate,
        "mean_isi": mean_isi,
        "std_isi": std_isi,
        "cv": cv
    }
    

results = []

for I_val in input_currents:
    features = run_simulation(I_val)
    results.append(features)

dataset = pd.DataFrame(results)
dataset["label"] = (dataset["I"] >= 6).astype(int)
dataset
# Out:
#    I  spike_count  firing_rate  mean_isi   std_isi        cv  label
# 0  2          2.0         20.0       NaN       NaN       NaN      0
# 1  4         14.0        140.0  6.961538  0.216754  0.031136      0
# 2  6         24.0        240.0  4.043478  0.113544  0.028081      1
# 3  8         34.0        340.0  2.909091  0.075332  0.025895      1

# %%
input_currents = [2,4,6,8]
def run_two_neuron_simulation(I_value):
    #Neuron A
    V_rest = -65
    V_th = -63
    V_reset = -65
    tau = 10
    dt = 0.1
    T = 100
    time = np.arange(0, T, dt)
    noise_std = 1
    noise = np.random.normal(0,noise_std,len(time))

    V = np.zeros(len(time))
    V[0] = V_rest
    spikes = np.zeros(len(time))

    for t in range(1, len(time)):
        I_t = I_value + noise[t]
        dV = (-(V[t-1] - V_rest) + I_t) * (dt / tau)
        V[t] = V[t-1] + dV

        if V[t] >= V_th:
            spikes[t] = 1
            V[t] = V_reset

    #Neuron B
    V_B = np.zeros(len(time))
    V_B[0]= V_rest
    spikes_B= np.zeros(len(time))

    syn_current = np.zeros(len(time))
    w_AB= 40 #synaptic strength
    alpha = 0.98 # synaptic decay

    for t in range(1, len(time)):
        #synaptic integration from A
        syn_current[t] = alpha* syn_current[t-1] + w_AB * spikes[t-1]

         #membrane update
        dV_B = (-(V_B[t-1] - V_rest) + syn_current[t]) * (dt/tau)
        V_B[t] = V_B[t-1] + dv_B

        if V_B[t] >= V_th:
            spikes_B[t] = 1
            V_B[t] = V_rest

# %%
plt.figure(figsize=(10,4))

plt.subplot(2,1,1)
plt.plot(time,spikes_A)
plt.title("Neuron A Spike Train")

plt.subplot(2,1,2)
plt.plot(time,spikes_B)
plt.title("Neuron B Spike Train")

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
def extract_features(spikes):
    spike_times= time[spikes==1]
    isi= np.diff(spike_times)

    spike_count = np.sum(spikes)
    firing_rate = spike_count / (T/1000)

    if len(isi)>1 :
        mean_isi = np.mean(isi)
        cv = np.std(isi) / mean_isi
    else:
        mean_isi = cv= np.nan

    return spike_count,firing_rate,mean_isi,cv

features_A = extract_features(spikes_A)
features_B = extract_features(spikes_B)

features_A,features_B
# Out:
# ((np.float64(16.0),
#   np.float64(160.0),
#   np.float64(6.113333333333333),
#   np.float64(0.02224217890334913)),
#  (np.float64(4.0),
#   np.float64(40.0),
#   np.float64(12.433333333333332),
#   np.float64(0.07021877133355929)))

# %%
dataset.describe()
# Out:
#               I  spike_count  firing_rate  mean_isi   std_isi        cv  \
# count  4.000000     4.000000     4.000000  3.000000  3.000000  3.000000
# mean   5.000000    18.500000   185.000000  4.638036  0.135210  0.028371
# std    2.581989    13.699148   136.991484  2.090624  0.073158  0.002632
# min    2.000000     2.000000    20.000000  2.909091  0.075332  0.025895
# 25%    3.500000    11.000000   110.000000  3.476285  0.094438  0.026988
# 50%    5.000000    19.000000   190.000000  4.043478  0.113544  0.028081
# 75%    6.500000    26.500000   265.000000  5.502508  0.165149  0.029608
# max    8.000000    34.000000   340.000000  6.961538  0.216754  0.031136
#
#          label
# count  4.00000
# mean   0.50000
# std    0.57735
# min    0.00000
# 25%    0.00000
# 50%    0.50000
# 75%    1.00000
# max    1.00000

# %%
results_noise = []

for I_val in [2,4,6,8]:
    results_noise.append(run_simulation(I_val))

dataset_noise = pd.DataFrame(results_noise)
dataset_noise
# Out:
#    I  spike_count  firing_rate  mean_isi   std_isi        cv
# 0  2          2.0         20.0       NaN       NaN       NaN
# 1  4         14.0        140.0  6.992308  0.309991  0.044333
# 2  6         24.0        240.0  4.056522  0.140886  0.034731
# 3  8         34.0        340.0  2.900000  0.085280  0.029407

# %% [markdown]
# **Feature scaling & model**

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

features_noise = dataset_noise[["spike_count","firing_rate","mean_isi","std_isi","cv"]]
features_noise = features_noise.dropna()

scaler = StandardScaler()
X_noise = scaler.fit_transform(features_noise)

y_noise = (dataset_noise.loc[features_noise.index,"I"]>=6).astype(int)

model_noise = LogisticRegression()
model_noise.fit(X_noise,y_noise)
# Out:
# LogisticRegression()

# %%
importance_noise = pd.Series(
    model_noise.coef_[0],
    index=features_noise.columns
).sort_values(ascending=False)

importance_noise
# Out:
# spike_count    0.320107
# firing_rate    0.320107
# cv            -0.377744
# mean_isi      -0.402819
# std_isi       -0.413491
# dtype: float64

# %%
#Input current vs firing rate
plt.figure(figsize=(6,4))
plt.plot(dataset["I"],dataset["firing_rate"],marker='o')
plt.xlabel("Input Current (I)")
plt.ylabel("Firing Rate (Hz)")
plt.title("Firing Rate vs Input Current")
plt.plot()
# Out:
# []

# %%
#Input Curent vs Mean ISI
plt.figure(figsize=(6,4))
plt.plot(dataset["I"],dataset["mean_isi"],marker='o')
plt.xlabel("Input Current (I)")
plt.ylabel("Mean ISI (ms)")
plt.title("Mean ISI vs Input Current")
plt.plot()
# Out:
# []

# %%
#Feature Correlation
dataset[["spike_count","firing_rate","mean_isi","std_isi","cv"]].corr()
# Out:
#              spike_count  firing_rate  mean_isi   std_isi        cv
# spike_count     1.000000     1.000000 -0.969196 -0.966551 -0.995440
# firing_rate     1.000000     1.000000 -0.969196 -0.966551 -0.995440
# mean_isi       -0.969196    -0.969196  1.000000  0.999945  0.988270
# std_isi        -0.966551    -0.966551  0.999945  1.000000  0.986608
# cv             -0.995440    -0.995440  0.988270  0.986608  1.000000

# %% [markdown]
# ## Feature Scaling

# %%
features= dataset[["spike_count","firing_rate","mean_isi","std_isi","cv"]]

scaler = StandardScaler()
scaled_features= scaler.fit_transform(features)

scaled_df = pd.DataFrame(
    scaled_features,
    columns=features.columns
)

scaled_df
# Out:
#    spike_count  firing_rate  mean_isi   std_isi        cv
# 0    -1.390784    -1.390784       NaN       NaN       NaN
# 1    -0.379305    -0.379305  1.361172  1.365134  1.286609
# 2     0.463595     0.463595 -0.348308 -0.362712 -0.134897
# 3     1.306494     1.306494 -1.012864 -1.002422 -1.151712

# %% [markdown]
# ## Why Scaling matters ?
#
# **Without scaling:**
# - firing rate dominates
# - ISI-bases features got ignored
#
# **With scaling:**
# - model can see all features
# - interpretation becomes meaningful

# %% [markdown]
# ## Handle NaNs

# %%
scaled_df.isna().sum()
X=scaled_df
y= dataset["label"]

valid_idx = ~scaled_df.isna().any(axis=1)
X_clean = scaled_df[valid_idx]
y_clean = y[valid_idx]

# %% [markdown]
# ## Logistic Regression

# %%
model = LogisticRegression()
model.fit(X_clean,y_clean)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Predictions

# %%
predictions = model.predict(X_clean)
predictions
# Out:
# array([0, 1, 1])

# %%
y_clean.values
# Out:
# array([0, 1, 1])

# %% [markdown]
# ## Accuracy

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_clean,predictions)
# Out:
# 1.0

# %% [markdown]
# ## Feature importance

# %%
importance = pd.Series(
    model.coef_[0],
    index=X_clean.columns
).sort_values(ascending=False)

importance
# Out:
# spike_count    0.251884
# firing_rate    0.251884
# cv            -0.403019
# mean_isi      -0.454601
# std_isi       -0.457763
# dtype: float64

# %% [markdown]
# ## Re-state
#
# Before interpreting, anchor the experiment:
#
# You simulated a LIF neuron
#
# You varied input current
#
# You extracted spike-based temporal features
#
# You trained a simple linear classifier
#
# The model separated low vs high input conditions
#
# This is a controlled computational experiment, not random ML.
#
# ## Interpret feature importance
#
# mean ISI (negative)
#
# CV & std of ISI (positive)
#
# spike count / firing rate
#
#
# Interpret each one biologically.
#
# 🔹 Mean ISI — Primary signal
#
# Higher input → faster membrane charging
#
# Faster charging → shorter time between spikes
#
# Therefore: mean ISI decreases with stronger input
#
# 🔹 ISI variability (CV, std) — Stability vs variability
#
# Low input → near-threshold dynamics → irregular timing
#
# High input → stable, fast spiking → less relative variability
#
# 🔹 Firing rate & spike count — Classic rate code
#
# These features still matter:
#
# Strong input → more spikes
#
# This is expected and biologically valid
#
#
# ## Big neuroscience insight (THIS IS GOLD)
#
# The results demonstrate:
#
# Neural information is encoded jointly in firing rate and spike timing structure.
#
# This directly aligns with:
#
# temporal coding theories
#
# population coding
#
# computational neuroscience literature
#
#
# ## Why logistic regression was the right choice
#
# Logistic regression was perfect because:
#
# linear
#
# interpretable
#
# coefficients map directly to feature importance
#
# For research, clarity > performance.

# %% [markdown]
# ## Limitaions till now
# - The dataset size is small
# - Deterministic dynamics
# - Single-neuron simulation model

# %% [markdown]
# # Observation
# Extending the model to a two-neuron circuit demonstrates how neural information is transformed through synaptic integration.
# Although Neuron B receives spikes directly from Neuron A, its firing rate is reduced and spike timing is altered.
# This illustrates that downstream neurons filter and reshape incoming spike trains rather than passively relaying activity, highlighting circuit-level computation.
